# %%
import subprocess
import pathlib
import sys

# === USER CONFIG ===
TOKTX_PATH = "toktx"  # Replace with your toktx.exe path
INPUT_FOLDER = pathlib.Path(".")  # Replace with your image folder
OUTPUT_FOLDER = INPUT_FOLDER  # Output folder (auto-created)

# === Setup ===
OUTPUT_FOLDER.mkdir(exist_ok=True)

# Supported input formats
VALID_EXTS = {'.png', '.jpg', '.jpeg', '.bmp', '.tga', '.psd', '.gif'}

# Convert files
for img_path in INPUT_FOLDER.iterdir():
    if img_path.suffix.lower() not in VALID_EXTS:
        continue

    out_path = OUTPUT_FOLDER / (img_path.stem + ".ktx2")

    print(f"Converting: {img_path.name} → {out_path.name}")

    result = subprocess.run([
        str(TOKTX_PATH),
        "--t2",              # Output KTX2 format
        "--bcmp",            # Basis Universal UASTC compression (visually lossless)
        "--genmipmap",       # Generate mipmaps
        str(out_path),
        str(img_path)
    ], capture_output=True, text=True)

    if result.returncode != 0:
        print(f"❌ Failed to convert {img_path.name}")
        print(result.stderr)
    else:
        print(f"✅ {out_path.name} created")

print("🎉 Done!")
# Out:
# Converting: b-box-t1.png → b-box-t1.ktx2
# ✅ b-box-t1.ktx2 created
# Converting: b-box-t2.png → b-box-t2.ktx2
# ✅ b-box-t2.ktx2 created
# Converting: b-sones-t1-c1.png → b-sones-t1-c1.ktx2
# ✅ b-sones-t1-c1.ktx2 created
# Converting: b-sones-t1-c2.png → b-sones-t1-c2.ktx2
# ✅ b-sones-t1-c2.ktx2 created
# Converting: b-sones-t1-c3.png → b-sones-t1-c3.ktx2
# ✅ b-sones-t1-c3.ktx2 created
# Converting: b-sones-t1-c4.png → b-sones-t1-c4.ktx2
# ✅ b-sones-t1-c4.ktx2 created
# Converting: b-sones-t1-c5.png → b-sones-t1-c5.ktx2
# ✅ b-sones-t1-c5.ktx2 created
# Converting: b-sones-t1-c6.png → b-sones-t1-c6.ktx2
# ✅ b-sones-t1-c6.ktx2 created
# Converting: b-sones-t1-c7.png → b-sones-t1-c7.ktx2
# ✅ b-sones-t1-c7.ktx2 created
# Converting: b-sones-t2-c1.png → b-sones-t2-c1.ktx2
# ✅ b-sones-t2-c1.ktx2 created
# Converting: b-sones-t2-c2.png → b-sones-t2-c2.ktx2
# ✅ b-sones-t2-c2.ktx2 created
# Converting: b-sones-t2-c3.png → b-sones-t2-c3.ktx2
# ✅ b-sones-t2-c3.ktx2 created
# Converting: b-sones-t2-c4.png → b-sones-t2-c4.ktx2
# ✅ b-sones-t2-c4.ktx2 created
# Converting: b-sones-t2-c5.png → b-sones-t2-c5.ktx2
# ✅ b-sones-t2-c5.ktx2 created
# Converting: b-sones-t2-c6.png → b-sones-t2-c6.ktx2
# ✅ b-sones-t2-c6.ktx2 created
# Converting: b-sones-t2-c7.png → b-sones-t2-c7.ktx2
# ✅ b-sones-t2-c7.ktx2 created
# Converting: b-sones-t3-c1.png → b-sones-t3-c1.ktx2
# ✅ b-sones-t3-c1.ktx2 created
# Converting: b-sones-t3-c2.png → b-sones-t3-c2.ktx2
# ✅ b-sones-t3-c2.ktx2 created
# Converting: b-sones-t3-c3.png → b-sones-t3-c3.ktx2
# ✅ b-sones-t3-c3.ktx2 created
# Converting: b-sones-t3-c4.png → b-sones-t3-c4.ktx2
# ✅ b-sones-t3-c4.ktx2 created
# Converting: b-sones-t3-c5.png → b-sones-t3-c5.ktx2
# ✅ b-sones-t3-c5.ktx2 created
# Converting: b-sones-t3-c6.png → b-sones-t3-c6.ktx2
# ✅ b-sones-t3-c6.ktx2 created
# Converting: b-sones-t3-c7.png → b-sones-t3-c7.ktx2
# ✅ b-sones-t3-c7.ktx2 created
# Converting: b-sones-t4-c1.png → b-sones-t4-c1.ktx2
# ✅ b-sones-t4-c1.ktx2 created
# Converting: b-sones-t4-c2.png → b-sones-t4-c2.ktx2
# ✅ b-sones-t4-c2.ktx2 created
# Converting: b-sones-t4-c3.png → b-sones-t4-c3.ktx2
# ✅ b-sones-t4-c3.ktx2 created
# Converting: b-sones-t4-c4.png → b-sones-t4-c4.ktx2
# ✅ b-sones-t4-c4.ktx2 created
# Converting: b-sones-t4-c5.png → b-sones-t4-c5.ktx2
# ✅ b-sones-t4-c5.ktx2 created
# Converting: b-sones-t4-c6.png → b-sones-t4-c6.ktx2
# ✅ b-sones-t4-c6.ktx2 created
# Converting: b-sones-t4-c7.png → b-sones-t4-c7.ktx2
# ✅ b-sones-t4-c7.ktx2 created
# Converting: b-sones-t5-c1.png → b-sones-t5-c1.ktx2
# ✅ b-sones-t5-c1.ktx2 created
# Converting: b-sones-t5-c2.png → b-sones-t5-c2.ktx2
# ✅ b-sones-t5-c2.ktx2 created
# Converting: b-sones-t5-c3.png → b-sones-t5-c3.ktx2
# ✅ b-sones-t5-c3.ktx2 created
# Converting: b-sones-t5-c4.png → b-sones-t5-c4.ktx2
# ✅ b-sones-t5-c4.ktx2 created
# Converting: b-sones-t5-c5.png → b-sones-t5-c5.ktx2
# ✅ b-sones-t5-c5.ktx2 created
# Converting: b-sones-t5-c6.png → b-sones-t5-c6.ktx2
# ✅ b-sones-t5-c6.ktx2 created
# Converting: b-sones-t5-c7.png → b-sones-t5-c7.ktx2
# ✅ b-sones-t5-c7.ktx2 created
# Converting: barrel-pomp-c1.png → barrel-pomp-c1.ktx2
# ✅ barrel-pomp-c1.ktx2 created
# Converting: barrel-pomp-c2.png → barrel-pomp-c2.ktx2
# ✅ barrel-pomp-c2.ktx2 created
# Converting: barrel-pomp-c3.png → barrel-pomp-c3.ktx2
# ✅ barrel-pomp-c3.ktx2 created
# Converting: barrel-pomp-c4.png → barrel-pomp-c4.ktx2
# ✅ barrel-pomp-c4.ktx2 created
# Converting: barrel-pomp-c5.png → barrel-pomp-c5.ktx2
# ✅ barrel-pomp-c5.ktx2 created
# Converting: barrel-pomp-c6.png → barrel-pomp-c6.ktx2
# ✅ barrel-pomp-c6.ktx2 created
# Converting: barrel-t1-c1.png → barrel-t1-c1.ktx2
# ✅ barrel-t1-c1.ktx2 created
# Converting: barrel-t1-c10.png → barrel-t1-c10.ktx2
# ✅ barrel-t1-c10.ktx2 created
# Converting: barrel-t1-c11.png → barrel-t1-c11.ktx2
# ✅ barrel-t1-c11.ktx2 created
# Converting: barrel-t1-c12.png → barrel-t1-c12.ktx2
# ✅ barrel-t1-c12.ktx2 created
# Converting: barrel-t1-c2.png → barrel-t1-c2.ktx2
# ✅ barrel-t1-c2.ktx2 created
# Converting: barrel-t1-c3.png → barrel-t1-c3.ktx2
# ✅ barrel-t1-c3.ktx2 created
# Converting: barrel-t1-c4.png → barrel-t1-c4.ktx2
# ✅ barrel-t1-c4.ktx2 created
# Converting: barrel-t1-c5.png → barrel-t1-c5.ktx2
# ✅ barrel-t1-c5.ktx2 created
# Converting: barrel-t1-c6.png → barrel-t1-c6.ktx2
# ✅ barrel-t1-c6.ktx2 created
# Converting: barrel-t1-c7.png → barrel-t1-c7.ktx2
# ✅ barrel-t1-c7.ktx2 created
# Converting: barrel-t1-c8.png → barrel-t1-c8.ktx2
# ✅ barrel-t1-c8.ktx2 created
# Converting: barrel-t1-c9.png → barrel-t1-c9.ktx2
# ✅ barrel-t1-c9.ktx2 created
# Converting: barrel-t2-c1.png → barrel-t2-c1.ktx2
# ✅ barrel-t2-c1.ktx2 created
# Converting: barrel-t2-c10.png → barrel-t2-c10.ktx2
# ✅ barrel-t2-c10.ktx2 created
# Converting: barrel-t2-c11.png → barrel-t2-c11.ktx2
# ✅ barrel-t2-c11.ktx2 created
# Converting: barrel-t2-c12.png → barrel-t2-c12.ktx2
# ✅ barrel-t2-c12.ktx2 created
# Converting: barrel-t2-c2.png → barrel-t2-c2.ktx2
# ✅ barrel-t2-c2.ktx2 created
# Converting: barrel-t2-c3.png → barrel-t2-c3.ktx2
# ✅ barrel-t2-c3.ktx2 created
# Converting: barrel-t2-c4.png → barrel-t2-c4.ktx2
# ✅ barrel-t2-c4.ktx2 created
# Converting: barrel-t2-c5.png → barrel-t2-c5.ktx2
# ✅ barrel-t2-c5.ktx2 created
# Converting: barrel-t2-c6.png → barrel-t2-c6.ktx2
# ✅ barrel-t2-c6.ktx2 created
# Converting: barrel-t2-c7.png → barrel-t2-c7.ktx2
# ✅ barrel-t2-c7.ktx2 created
# Converting: barrel-t2-c8.png → barrel-t2-c8.ktx2
# ✅ barrel-t2-c8.ktx2 created
# Converting: barrel-t2-c9.png → barrel-t2-c9.ktx2
# ✅ barrel-t2-c9.ktx2 created
# Converting: barrel-t3-c1.png → barrel-t3-c1.ktx2
# ✅ barrel-t3-c1.ktx2 created
# Converting: barrel-t3-c10.png → barrel-t3-c10.ktx2
# ✅ barrel-t3-c10.ktx2 created
# Converting: barrel-t3-c11.png → barrel-t3-c11.ktx2
# ✅ barrel-t3-c11.ktx2 created
# Converting: barrel-t3-c12.png → barrel-t3-c12.ktx2
# ✅ barrel-t3-c12.ktx2 created
# Converting: barrel-t3-c2.png → barrel-t3-c2.ktx2
# ✅ barrel-t3-c2.ktx2 created
# Converting: barrel-t3-c3.png → barrel-t3-c3.ktx2
# ✅ barrel-t3-c3.ktx2 created
# Converting: barrel-t3-c4.png → barrel-t3-c4.ktx2
# ✅ barrel-t3-c4.ktx2 created
# Converting: barrel-t3-c5.png → barrel-t3-c5.ktx2
# ✅ barrel-t3-c5.ktx2 created
# Converting: barrel-t3-c6.png → barrel-t3-c6.ktx2
# ✅ barrel-t3-c6.ktx2 created
# Converting: barrel-t3-c7.png → barrel-t3-c7.ktx2
# ✅ barrel-t3-c7.ktx2 created
# Converting: barrel-t3-c8.png → barrel-t3-c8.ktx2
# ✅ barrel-t3-c8.ktx2 created
# Converting: barrel-t3-c9.png → barrel-t3-c9.ktx2
# ✅ barrel-t3-c9.ktx2 created
# Converting: barrel-t4-c1.png → barrel-t4-c1.ktx2
# ✅ barrel-t4-c1.ktx2 created
# Converting: barrel-t4-c10.png → barrel-t4-c10.ktx2
# ✅ barrel-t4-c10.ktx2 created
# Converting: barrel-t4-c11.png → barrel-t4-c11.ktx2
# ✅ barrel-t4-c11.ktx2 created
# Converting: barrel-t4-c12.png → barrel-t4-c12.ktx2
# ✅ barrel-t4-c12.ktx2 created
# Converting: barrel-t4-c2.png → barrel-t4-c2.ktx2
# ✅ barrel-t4-c2.ktx2 created
# Converting: barrel-t4-c3.png → barrel-t4-c3.ktx2
# ✅ barrel-t4-c3.ktx2 created
# Converting: barrel-t4-c4.png → barrel-t4-c4.ktx2
# ✅ barrel-t4-c4.ktx2 created
# Converting: barrel-t4-c5.png → barrel-t4-c5.ktx2
# ✅ barrel-t4-c5.ktx2 created
# Converting: barrel-t4-c6.png → barrel-t4-c6.ktx2
# ✅ barrel-t4-c6.ktx2 created
# Converting: barrel-t4-c7.png → barrel-t4-c7.ktx2
# ✅ barrel-t4-c7.ktx2 created
# Converting: barrel-t4-c8.png → barrel-t4-c8.ktx2
# ✅ barrel-t4-c8.ktx2 created
# Converting: barrel-t4-c9.png → barrel-t4-c9.ktx2
# ✅ barrel-t4-c9.ktx2 created
# Converting: barrel-t5-c1.png → barrel-t5-c1.ktx2
# ✅ barrel-t5-c1.ktx2 created
# Converting: barrel-t5-c10.png → barrel-t5-c10.ktx2
# ✅ barrel-t5-c10.ktx2 created
# Converting: barrel-t5-c11.png → barrel-t5-c11.ktx2
# ✅ barrel-t5-c11.ktx2 created
# Converting: barrel-t5-c12.png → barrel-t5-c12.ktx2
# ✅ barrel-t5-c12.ktx2 created
# Converting: barrel-t5-c2.png → barrel-t5-c2.ktx2
# ✅ barrel-t5-c2.ktx2 created
# Converting: barrel-t5-c3.png → barrel-t5-c3.ktx2
# ✅ barrel-t5-c3.ktx2 created
# Converting: barrel-t5-c4.png → barrel-t5-c4.ktx2
# ✅ barrel-t5-c4.ktx2 created
# Converting: barrel-t5-c5.png → barrel-t5-c5.ktx2
# ✅ barrel-t5-c5.ktx2 created
# Converting: barrel-t5-c6.png → barrel-t5-c6.ktx2
# ✅ barrel-t5-c6.ktx2 created
# Converting: barrel-t5-c7.png → barrel-t5-c7.ktx2
# ✅ barrel-t5-c7.ktx2 created
# Converting: barrel-t5-c8.png → barrel-t5-c8.ktx2
# ✅ barrel-t5-c8.ktx2 created
# Converting: barrel-t5-c9.png → barrel-t5-c9.ktx2
# ✅ barrel-t5-c9.ktx2 created
# Converting: bg_l1_fr_1.png → bg_l1_fr_1.ktx2
# ✅ bg_l1_fr_1.ktx2 created
# Converting: bg_l1_fr_2.png → bg_l1_fr_2.ktx2
# ✅ bg_l1_fr_2.ktx2 created
# Converting: bg_l1_fr_3.png → bg_l1_fr_3.ktx2
# ✅ bg_l1_fr_3.ktx2 created
# Converting: bg_lf1.png → bg_lf1.ktx2
# ✅ bg_lf1.ktx2 created
# Converting: bg_lf2.png → bg_lf2.ktx2
# ✅ bg_lf2.ktx2 created
# Converting: bg_lf3.png → bg_lf3.ktx2
# ✅ bg_lf3.ktx2 created
# Converting: bg_lf4.png → bg_lf4.ktx2
# ✅ bg_lf4.ktx2 created
# Converting: bg_lf5.png → bg_lf5.ktx2
# ✅ bg_lf5.ktx2 created
# Converting: bg_stars-2.png → bg_stars-2.ktx2
# ✅ bg_stars-2.ktx2 created
# Converting: bg_stars-3.png → bg_stars-3.ktx2
